# %%
import requests
import json
import sklearn
import pandas as pd
import numpy as np
import csv
import math
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
import tensorflow as tf


from config import api_key

from pprint import pprint
# Out:
# C:\Users\ahumb\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Setting up URL and pull of League Data

# %%
# Original example from Collin
# League_url = f"http://api.sportradar.us/ncaamb/trial/v4/en/league/hierarchy.json?+{api_key}"

# added "api_key=" to the end of the URLs, changed URLs to be strings
# added api_key in the requests.get cells

#Team_url = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/fae4855b-1b64-4b40-a632-9ed345e1e952/statistics.json?api_key=" #+{api_key}
#Team_url = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/statistics.json?api_key=" #+{api_key}

#/ncaamb/trial/v4/en/seasons/2016/reg/teams/2f4d21f8-6d5f-48a5-abca-52a30583871a/statistics.xml?api_key=

League_url = "http://api.sportradar.us/ncaamb/trial/v4/en/league/hierarchy.json?api_key="


format = "json"

# %%
#League_url = f"http://api.sportradar.us/ncaamb/trial/v4/en/league/hierarchy.json?+{api_key}"
#format = "json"

# %%
# Reformatted the requests.get
League_response = requests.get(League_url + api_key).json()


#League_response

# %%
# Looking at data shape of the League level
# print(json.dumps(League_response, indent=4, sort_keys=True))

# %%
#division level - 7 is the NCAA D1
d1 = League_response["divisions"][7] ["conferences"]#[0]
#d1

# %%
#conference level
conferences = d1[0]["teams"]
#conferences

# %%
teams = conferences[0]["venue"]
#teams

# %%
#Breakdown of Conferences and teams within conference, along with IDs
#included city and state to the output


conference_names = []
conference_ids = []
team_names = []
team_ids = []
team_market = []
team_city = []
team_state = []


for i in range(0,len(d1)):
    conferences = d1[i]["teams"]
    for j in range(0,len(conferences)):
        teams = conferences[j]["venue"]
        for k in range (0,len(teams)):
            #print(d1[i]["name"])
            #print(d1[i]["id"])
            #print(conferences[j]["name"])
            #print(conferences[j]["id"])
            conference_names.append(d1[i]["name"])
            conference_ids.append(d1[i]["id"])
            team_market.append(conferences[j]["market"])
            team_names.append(conferences[j]["name"])
            team_ids.append(conferences[j]["id"])
            team_city.append(conferences[j]["venue"]["city"])
            team_state.append(conferences[j]["venue"]["state"])

# %%
#for j in range(0,len(conferences)):
        #teams = conferences[j]["venue"]
        #for k in range (0,len(teams)):
            #team_names.append(conferences[j]["name"])
            #team_ids.append(conferences[j]["id"])
            #team_city.append(conferences[j]["venue"]["city"])
            #team_state.append(conferences[j]["venue"]["state"])

# %%
#conferences[0]["venue"]

# %%
# using zip
zippedList = list(zip(team_market,team_names,team_ids,team_city,team_state,conference_names,conference_ids))
#zippedList

# %%
# turning zipped list into a DF
#teamdf = pd.DataFrame(zippedList,columns = [team_name,team_id,conference_name,conference_id],index=[])
teamdf = pd.DataFrame({"team_market":team_market,
                      "team_name":team_names,
                      "team_id":team_ids,
                       "team_city":team_city,
                       "team_state":team_state,
                      "conference_name":conference_names,
                       "conference_id":conference_ids                       
                      })

#teamdf

# %%
#teamdf
teamdf.to_csv("team_conference_with_id_and_loc.csv", index=False)

# %%
#trying to set up list of teams... team_ids is already a list, team_ids_df is a datafram
#trying to use one of these to loop through a requests.get for teh teams
#team_ids_df = pd.DataFrame({"team_id":team_ids})
#team_ids

# %%
#team_id

#for i in range(0,len(d1)):
    #conferences = d1[i]["teams"]
    #for j in range(0,len(conferences)):
        #print(d1[i]["name"])
        #print(d1[i]["id"])
        #print(conferences[j]["name"])
        #print(conferences[j]["id"])
        #conference_name.append(d1[i]["name"])
        #conference_id.append(d1[i]["id"])
        #team_name.append(conferences[j]["name"])
        #team_id.append(conferences[j]["id"])
        
#for j in range(0,len(conferences)):
        #print(d1[i]["name"])
        #print(d1[i]["id"])
        #print(conferences[j]["name"])
        #print(conferences[j]["id"])
        #conference_name.append(d1[i]["name"])
        #conference_id.append(d1[i]["id"])
        #team_name.append(conferences[j]["name"])
        #team_id.append(conferences[j]["id"])

# %%
#Team_response = requests.get(Team_url + api_key).json()
#Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"
#Team_url_2 = "/statistics.json?api_key="

#team_id -- this is taken from our lists

#Team_response = requests.get(Team_url_1 + team_id(i) + Team_url_2 + api_key).json()

# %%
#for team_id in team_ids:
    #Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"
    #Team_url_2 = "/statistics.json?api_key="
    #Team_response = requests.get(Team_url_1 + team_id + Team_url_2 + api_key).json()

#for k in range(0,len(team_id_df)):
    #Team_response = requests.get(Team_url_1 + team_id_df(k) + Team_url_2 + api_key).json()


    #for i in range(0,len(d1)):
            #Team_response = d1[i]["teams"]
            #for j in range(0,len(Team_response)):
                #print(d1[i]["name"])
                #print(d1[i]["id"])
                #print(conferences[j]["name"])
                #print(conferences[j]["id"])
                #conference_name.append(d1[i]["name"])
                #conference_id.append(d1[i]["id"])
                #team_name.append(Team_response[j]["name"])
                #team_id.append(Team_response[j]["id"])
        
                #teamdf = pd.DataFrame({"team_name":name,
                                      #"type":reg,
                                      #"conference_name":conference_name,
                                      #"conference_id":conference_id
                                      #})

# %%
#print(Team_response)

# %%
#d1 = League_response

# %%
#0d037a5d-827a-44dd-8b70-57603d671d5d
#04d5255d-b2dc-43df-9fa8-d296b0f8ccd7
#Team_url = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/0d037a5d-827a-44dd-8b70-57603d671d5d/statistics.json?api_key="
#Team_pretend_response = requests.get(Team_url + api_key).json()
#d1 = League_response["divisions"][7] ["conferences"]

# %%
#Team_pretend_response

# %%
#d1_team_data = Team_pretend_response #["divisions"][7] ["conferences"]

# %%
#defining empty lists here - BEFORE running URL and appends
#If we have to manually run 64 teams through, then we don't want to empty our lists each time

team_market = []
team_names = []
team_ids = []
#Total
total_games_played = []
total_minutes_played = []
total_field_goals_made = []
total_field_goals_att = []
total_minutes = []
total_field_goals_made = []
total_field_goals_att = []
total_field_goals_pct = []
total_two_points_made = []
total_two_points_att = []
total_two_points_pct = []
total_three_points_made = []
total_three_points_att = []
total_three_points_pct = []
total_blocked_att = []
total_free_throws_made = []
total_free_throws_att = []
total_free_throws_pct = []
total_offensive_rebounds = []
total_defensive_rebounds = []
total_rebounds = []
total_assists = []
total_turnovers = []
total_assists_turnover_ratio = []
total_steals = []
total_blocks = []
total_personal_fouls = []
total_tech_fouls = []
total_points = []
total_fast_break_pts = []
total_flagrant_fouls = []
total_points_off_turnovers = []
total_second_chance_pts = []
total_ejections = []
total_foulouts = []
total_points_in_paint = []
total_efficiency = []
total_true_shooting_att = []
total_true_shooting_pct = []
#Average
average_fast_break_pts = []
average_points_off_turnovers = []
average_second_chance_pts = []
average_minutes = []
average_points = []
average_off_rebounds = []
average_def_rebounds = []
average_rebounds = []
average_assists = []
average_steals = []
average_blocks = []
average_turnovers = []
average_personal_fouls = []
average_flagrant_fouls = []
average_blocked_att = []
average_field_goals_made = []
average_field_goals_att = []
average_three_points_made = []
average_three_points_att = []
average_free_throws_made = []
average_free_throws_att = []
average_two_points_made = []
average_two_points_att = []
average_points_in_paint = []
average_efficiency = []
average_true_shooting_att = []

# %%
#0d037a5d-827a-44dd-8b70-57603d671d5d
#1da70895-f77f-44ef-b216-d63c02e696eb
#2d4f0015-adb4-4877-8c15-4a6eed7eed03
Team_url_2 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/2d4f0015-adb4-4877-8c15-4a6eed7eed03/statistics.json?api_key="

# %%
teams_response_2 = requests.get(Team_url_2 + api_key ).json()


teams_response_2
# Out:
# {'id': '2d4f0015-adb4-4877-8c15-4a6eed7eed03',
#  'name': 'Cougars',
#  'market': 'Washington State',
#  'season': {'id': '6c78669c-a47f-41b8-8715-5482db4d8a45',
#   'year': 2018,
#   'type': 'REG'},
#  'own_record': {'total': {'games_played': 31,
#    'minutes': 6200.0,
#    'field_goals_made': 817,
#    'field_goals_att': 1809,
#    'field_goals_pct': 0.452,
#    'two_points_made': 523,
#    'two_points_att': 1013,
#    'two_points_pct': 0.516,
#    'three_points_made': 294,
#    'three_points_att': 796,
#    'three_points_pct': 0.369,
#    'blocked_att': 78,
#    'free_throws_made': 414,
#    'free_throws_att': 547,
#    'free_throws_pct': 0.757,
#    'offensive_rebounds': 235,
#    'defensive_rebounds': 731,
#    'rebounds': 966,
#    'assists': 463,
#    'turnovers': 419,
#    'assists_turnover_ratio': 1.11,
#    'steals': 164,
#    'blocks': 88,
#    'personal_fouls': 541,
#    'tech_fouls': 4,
#    'points': 2342,
#    'fast_break_pts': 371,
#    'flagrant_fouls': 2,
#    'points_off_turnovers': 438,
#    'second_chance_pts': 298,
#    'ejections': 0,
#    'foulouts': 11,
#    'points_in_paint': 836,
#    'efficiency': 2479,
#    'true_shooting_att': 2049.68,
#    'true_shooting_pct': 0.571},
#   'average': {'fast_break_pts': 11.97,
#    'points_off_turnovers': 14.13,
#    'second_chance_pts': 9.61,
#    'minutes': 200.0,
#    'points': 75.5,
#    'off_rebounds': 7.58,
#    'def_rebounds': 23.58,
#    'rebounds': 31.16,
#    'assists': 14.9,
#    'steals': 5.29,
#    'blocks': 2.84,
#    'turnovers': 13.52,
#    'personal_fouls': 17.45,
#    'flagrant_fouls': 0.06,
#    'blocked_att': 2.52,
#    'field_goals_made': 26.35,
#    'field_goals_att': 58.35,
#    'three_points_made': 9.48,
#    'three_points_att': 25.68,
#    'free_throws_made': 13.35,
#    'free_throws_att': 17.65,
#    'two_points_made': 16.87,
#    'two_points_att': 32.68,
#    'points_in_paint': 26.97,
#    'efficiency': 79.97,
#    'true_shooting_att': 66.12}},
#  'opponents': {'total': {'games_played': 31,
#    'minutes': 6200.0,
#    'field_goals_made': 894,
#    'field_goals_att': 1900,
#    'field_goals_pct': 0.471,
#    'two_points_made': 607,
#    'two_points_att': 1108,
#    'two_points_pct': 0.548,
#    'three_points_made': 287,
#    'three_points_att': 792,
#    'three_points_pct': 0.362,
#    'blocked_att': 89,
#    'free_throws_made': 358,
#    'free_throws_att': 548,
#    'free_throws_pct': 0.653,
#    'offensive_rebounds': 275,
#    'defensive_rebounds': 762,
#    'rebounds': 1037,
#    'assists': 477,
#    'turnovers': 376,
#    'assists_turnover_ratio': 1.27,
#    'steals': 219,
#    'blocks': 79,
#    'personal_fouls': 524,
#    'tech_fouls': 6,
#    'points': 2433,
#    'fast_break_pts': 346,
#    'flagrant_fouls': 3,
#    'points_off_turnovers': 500,
#    'second_chance_pts': 320,
#    'ejections': 0,
#    'foulouts': 14,
#    'points_in_paint': 1072,
#    'efficiency': 2673,
#    'true_shooting_att': 2141.12,
#    'true_shooting_pct': 0.568},
#   'average': {'fast_break_pts': 11.16,
#    'points_off_turnovers': 16.13,
#    'second_chance_pts': 10.32,
#    'minutes': 200.0,
#    'points': 78.5,
#    'off_rebounds': 8.87,
#    'def_rebounds': 24.58,
#    'rebounds': 33.45,
#    'assists': 15.4,
#    'steals': 7.06,
#    'blocks': 2.55,
#    'turnovers': 12.13,
#    'personal_fouls': 16.9,
#    'flagrant_fouls': 0.1,
#    'blocked_att': 2.87,
#    'field_goals_made': 28.84,
#    'field_goals_att': 61.29,
#    'three_points_made': 9.26,
#    'three_points_att': 25.55,
#    'free_throws_made': 11.55,
#    'free_throws_att': 17.68,
#    'two_points_made': 19.58,
#    'two_points_att': 35.74,
#    'points_in_paint': 34.58,
#    'efficiency': 86.23,
#    'true_shooting_att': 69.07}},
#  'players': [{'id': '06c5d14b-0905-4545-a91a-b1df2e3bc63e',
#    'full_name': 'Ahmed Ali',
#    'first_name': 'Ahmed',
#    'last_name': 'Ali',
#    'position': 'G',
#    'primary_position': 'NA',
#    'jersey_number': '23',
#    'total': {'games_played': 31,
#     'games_started': 24,
#     'minutes': 670.0,
#     'field_goals_made': 76,
#     'field_goals_att': 200,
#     'field_goals_pct': 0.38,
#     'two_points_made': 31,
#     'two_points_att': 66,
#     'two_points_pct': 0.47,
#     'three_points_made': 45,
#     'three_points_att': 134,
#     'three_points_pct': 0.336,
#     'blocked_att': 12,
#     'free_throws_made': 36,
#     'free_throws_att': 44,
#     'free_throws_pct': 0.818,
#     'offensive_rebounds': 18,
#     'defensive_rebounds': 40,
#     'rebounds': 58,
#     'assists': 92,
#     'turnovers': 39,
#     'assists_turnover_ratio': 2.36,
#     'steals': 23,
#     'blocks': 1,
#     'personal_fouls': 68,
#     'tech_fouls': 0,
#     'points': 233,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 2,
#     'true_shooting_att': 219.36,
#     'true_shooting_pct': 0.531,
#     'efficiency': 236},
#    'average': {'minutes': 21.6,
#     'points': 7.5,
#     'off_rebounds': 0.58,
#     'def_rebounds': 1.29,
#     'rebounds': 1.87,
#     'assists': 3.0,
#     'steals': 0.74,
#     'blocks': 0.03,
#     'turnovers': 1.26,
#     'personal_fouls': 2.19,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.39,
#     'field_goals_made': 2.45,
#     'field_goals_att': 6.45,
#     'three_points_made': 1.45,
#     'three_points_att': 4.32,
#     'free_throws_made': 1.16,
#     'free_throws_att': 1.42,
#     'two_points_made': 1.0,
#     'two_points_att': 2.13,
#     'efficiency': 7.61,
#     'true_shooting_att': 7.08}},
#   {'id': '20473f38-1ee3-4642-8b32-cdebe5ef8031',
#    'full_name': 'Jeff Pollard',
#    'first_name': 'Jeff',
#    'last_name': 'Pollard',
#    'position': 'F',
#    'primary_position': 'NA',
#    'jersey_number': '13',
#    'total': {'games_played': 28,
#     'games_started': 22,
#     'minutes': 500.0,
#     'field_goals_made': 54,
#     'field_goals_att': 91,
#     'field_goals_pct': 0.593,
#     'two_points_made': 52,
#     'two_points_att': 83,
#     'two_points_pct': 0.627,
#     'three_points_made': 2,
#     'three_points_att': 8,
#     'three_points_pct': 0.25,
#     'blocked_att': 6,
#     'free_throws_made': 25,
#     'free_throws_att': 32,
#     'free_throws_pct': 0.781,
#     'offensive_rebounds': 24,
#     'defensive_rebounds': 46,
#     'rebounds': 70,
#     'assists': 16,
#     'turnovers': 16,
#     'assists_turnover_ratio': 1.0,
#     'steals': 11,
#     'blocks': 2,
#     'personal_fouls': 40,
#     'tech_fouls': 0,
#     'points': 135,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 0,
#     'true_shooting_att': 105.08,
#     'true_shooting_pct': 0.642,
#     'efficiency': 174},
#    'average': {'minutes': 17.9,
#     'points': 4.8,
#     'off_rebounds': 0.86,
#     'def_rebounds': 1.64,
#     'rebounds': 2.5,
#     'assists': 0.6,
#     'steals': 0.39,
#     'blocks': 0.07,
#     'turnovers': 0.57,
#     'personal_fouls': 1.43,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.21,
#     'field_goals_made': 1.93,
#     'field_goals_att': 3.25,
#     'three_points_made': 0.07,
#     'three_points_att': 0.29,
#     'free_throws_made': 0.89,
#     'free_throws_att': 1.14,
#     'two_points_made': 1.86,
#     'two_points_att': 2.96,
#     'efficiency': 6.21,
#     'true_shooting_att': 3.75}},
#   {'id': '3f56a1e0-0993-4af9-b56e-2ec6af6c03eb',
#    'full_name': "Viont'e Daniels",
#    'first_name': "Viont'e",
#    'last_name': 'Daniels',
#    'position': 'G',
#    'primary_position': 'NA',
#    'jersey_number': '24',
#    'total': {'games_played': 24,
#     'games_started': 19,
#     'minutes': 589.0,
#     'field_goals_made': 48,
#     'field_goals_att': 116,
#     'field_goals_pct': 0.414,
#     'two_points_made': 12,
#     'two_points_att': 27,
#     'two_points_pct': 0.444,
#     'three_points_made': 36,
#     'three_points_att': 89,
#     'three_points_pct': 0.404,
#     'blocked_att': 4,
#     'free_throws_made': 17,
#     'free_throws_att': 18,
#     'free_throws_pct': 0.944,
#     'offensive_rebounds': 6,
#     'defensive_rebounds': 36,
#     'rebounds': 42,
#     'assists': 64,
#     'turnovers': 24,
#     'assists_turnover_ratio': 2.67,
#     'steals': 13,
#     'blocks': 6,
#     'personal_fouls': 36,
#     'tech_fouls': 0,
#     'points': 149,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 0,
#     'true_shooting_att': 123.92,
#     'true_shooting_pct': 0.601,
#     'efficiency': 181},
#    'average': {'minutes': 24.5,
#     'points': 6.2,
#     'off_rebounds': 0.25,
#     'def_rebounds': 1.5,
#     'rebounds': 1.75,
#     'assists': 2.7,
#     'steals': 0.54,
#     'blocks': 0.25,
#     'turnovers': 1.0,
#     'personal_fouls': 1.5,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.17,
#     'field_goals_made': 2.0,
#     'field_goals_att': 4.83,
#     'three_points_made': 1.5,
#     'three_points_att': 3.71,
#     'free_throws_made': 0.71,
#     'free_throws_att': 0.75,
#     'two_points_made': 0.5,
#     'two_points_att': 1.13,
#     'efficiency': 7.54,
#     'true_shooting_att': 5.16}},
#   {'id': '4c9f78bb-5d13-4ab6-ac6a-099189d54713',
#    'full_name': 'Davante Cooper',
#    'first_name': 'Davante',
#    'last_name': 'Cooper',
#    'position': 'F',
#    'primary_position': 'NA',
#    'jersey_number': '32',
#    'total': {'games_played': 18,
#     'games_started': 3,
#     'minutes': 113.0,
#     'field_goals_made': 10,
#     'field_goals_att': 15,
#     'field_goals_pct': 0.667,
#     'two_points_made': 10,
#     'two_points_att': 15,
#     'two_points_pct': 0.667,
#     'three_points_made': 0,
#     'three_points_att': 0,
#     'three_points_pct': 0,
#     'blocked_att': 1,
#     'free_throws_made': 1,
#     'free_throws_att': 5,
#     'free_throws_pct': 0.2,
#     'offensive_rebounds': 6,
#     'defensive_rebounds': 13,
#     'rebounds': 19,
#     'assists': 4,
#     'turnovers': 11,
#     'assists_turnover_ratio': 0.36,
#     'steals': 1,
#     'blocks': 5,
#     'personal_fouls': 15,
#     'tech_fouls': 0,
#     'points': 21,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 0,
#     'true_shooting_att': 17.2,
#     'true_shooting_pct': 0.61,
#     'efficiency': 30},
#    'average': {'minutes': 6.3,
#     'points': 1.2,
#     'off_rebounds': 0.33,
#     'def_rebounds': 0.72,
#     'rebounds': 1.06,
#     'assists': 0.2,
#     'steals': 0.06,
#     'blocks': 0.28,
#     'turnovers': 0.61,
#     'personal_fouls': 0.83,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.06,
#     'field_goals_made': 0.56,
#     'field_goals_att': 0.83,
#     'three_points_made': 0.0,
#     'three_points_att': 0.0,
#     'free_throws_made': 0.06,
#     'free_throws_att': 0.28,
#     'two_points_made': 0.56,
#     'two_points_att': 0.83,
#     'efficiency': 1.67,
#     'true_shooting_att': 0.96}},
#   {'id': '54c69728-3315-4ae4-b6f9-712e6c6887c4',
#    'full_name': 'James Streeter',
#    'first_name': 'James',
#    'last_name': 'Streeter',
#    'position': 'C',
#    'primary_position': 'NA',
#    'jersey_number': '15',
#    'total': {'games_played': 0,
#     'games_started': 0,
#     'minutes': 0.0,
#     'field_goals_made': 0,
#     'field_goals_att': 0,
#     'field_goals_pct': 0,
#     'two_points_made': 0,
#     'two_points_att': 0,
#     'two_points_pct': 0,
#     'three_points_made': 0,
#     'three_points_att': 0,
#     'three_points_pct': 0,
#     'blocked_att': 0,
#     'free_throws_made': 0,
#     'free_throws_att': 0,
#     'free_throws_pct': 0,
#     'offensive_rebounds': 0,
#     'defensive_rebounds': 0,
#     'rebounds': 0,
#     'assists': 0,
#     'turnovers': 0,
#     'assists_turnover_ratio': 0,
#     'steals': 0,
#     'blocks': 0,
#     'personal_fouls': 0,
#     'tech_fouls': 0,
#     'points': 0,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 0,
#     'true_shooting_att': 0.0,
#     'true_shooting_pct': 0,
#     'efficiency': 0},
#    'average': {'minutes': 0,
#     'points': 0,
#     'off_rebounds': 0,
#     'def_rebounds': 0,
#     'rebounds': 0,
#     'assists': 0,
#     'steals': 0,
#     'blocks': 0,
#     'turnovers': 0,
#     'personal_fouls': 0,
#     'flagrant_fouls': 0,
#     'blocked_att': 0,
#     'field_goals_made': 0,
#     'field_goals_att': 0,
#     'three_points_made': 0,
#     'three_points_att': 0,
#     'free_throws_made': 0,
#     'free_throws_att': 0,
#     'two_points_made': 0,
#     'two_points_att': 0,
#     'efficiency': 0,
#     'true_shooting_att': 0}},
#   {'id': '644578de-10f1-4801-a005-80e413c2708e',
#    'full_name': 'Chance Moore',
#    'first_name': 'Chance',
#    'last_name': 'Moore',
#    'position': 'F',
#    'primary_position': 'NA',
#    'total': {'games_played': 0,
#     'games_started': 0,
#     'minutes': 0.0,
#     'field_goals_made': 0,
#     'field_goals_att': 0,
#     'field_goals_pct': 0,
#     'two_points_made': 0,
#     'two_points_att': 0,
#     'two_points_pct': 0,
#     'three_points_made': 0,
#     'three_points_att': 0,
#     'three_points_pct': 0,
#     'blocked_att': 0,
#     'free_throws_made': 0,
#     'free_throws_att': 0,
#     'free_throws_pct': 0,
#     'offensive_rebounds': 0,
#     'defensive_rebounds': 0,
#     'rebounds': 0,
#     'assists': 0,
#     'turnovers': 0,
#     'assists_turnover_ratio': 0,
#     'steals': 0,
#     'blocks': 0,
#     'personal_fouls': 0,
#     'tech_fouls': 0,
#     'points': 0,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 0,
#     'true_shooting_att': 0.0,
#     'true_shooting_pct': 0,
#     'efficiency': 0},
#    'average': {'minutes': 0,
#     'points': 0,
#     'off_rebounds': 0,
#     'def_rebounds': 0,
#     'rebounds': 0,
#     'assists': 0,
#     'steals': 0,
#     'blocks': 0,
#     'turnovers': 0,
#     'personal_fouls': 0,
#     'flagrant_fouls': 0,
#     'blocked_att': 0,
#     'field_goals_made': 0,
#     'field_goals_att': 0,
#     'three_points_made': 0,
#     'three_points_att': 0,
#     'free_throws_made': 0,
#     'free_throws_att': 0,
#     'two_points_made': 0,
#     'two_points_att': 0,
#     'efficiency': 0,
#     'true_shooting_att': 0}},
#   {'id': '7e884ef1-6e13-4d48-ad05-c68db3046c2e',
#    'full_name': 'Robert Franks Jr.',
#    'first_name': 'Robert',
#    'last_name': 'Franks',
#    'position': 'F',
#    'primary_position': 'NA',
#    'jersey_number': '3',
#    'total': {'games_played': 26,
#     'games_started': 25,
#     'minutes': 896.0,
#     'field_goals_made': 199,
#     'field_goals_att': 399,
#     'field_goals_pct': 0.499,
#     'two_points_made': 124,
#     'two_points_att': 217,
#     'two_points_pct': 0.571,
#     'three_points_made': 75,
#     'three_points_att': 182,
#     'three_points_pct': 0.412,
#     'blocked_att': 18,
#     'free_throws_made': 102,
#     'free_throws_att': 121,
#     'free_throws_pct': 0.843,
#     'offensive_rebounds': 37,
#     'defensive_rebounds': 155,
#     'rebounds': 192,
#     'assists': 66,
#     'turnovers': 84,
#     'assists_turnover_ratio': 0.79,
#     'steals': 18,
#     'blocks': 19,
#     'personal_fouls': 66,
#     'tech_fouls': 1,
#     'points': 575,
#     'flagrant_fouls': 1,
#     'ejections': 0,
#     'foulouts': 2,
#     'true_shooting_att': 452.24,
#     'true_shooting_pct': 0.636,
#     'efficiency': 567},
#    'average': {'minutes': 34.5,
#     'points': 22.1,
#     'off_rebounds': 1.42,
#     'def_rebounds': 5.96,
#     'rebounds': 7.38,
#     'assists': 2.5,
#     'steals': 0.69,
#     'blocks': 0.73,
#     'turnovers': 3.23,
#     'personal_fouls': 2.54,
#     'flagrant_fouls': 0.04,
#     'blocked_att': 0.69,
#     'field_goals_made': 7.65,
#     'field_goals_att': 15.35,
#     'three_points_made': 2.88,
#     'three_points_att': 7.0,
#     'free_throws_made': 3.92,
#     'free_throws_att': 4.65,
#     'two_points_made': 4.77,
#     'two_points_att': 8.35,
#     'efficiency': 21.81,
#     'true_shooting_att': 17.39}},
#   {'id': '87865181-261c-4fb6-8aab-877faa20aa61',
#    'full_name': 'Arinze Chidom',
#    'first_name': 'Arinze',
#    'last_name': 'Chidom',
#    'position': 'F',
#    'primary_position': 'NA',
#    'total': {'games_played': 8,
#     'games_started': 2,
#     'minutes': 109.0,
#     'field_goals_made': 9,
#     'field_goals_att': 27,
#     'field_goals_pct': 0.333,
#     'two_points_made': 8,
#     'two_points_att': 20,
#     'two_points_pct': 0.4,
#     'three_points_made': 1,
#     'three_points_att': 7,
#     'three_points_pct': 0.143,
#     'blocked_att': 0,
#     'free_throws_made': 7,
#     'free_throws_att': 10,
#     'free_throws_pct': 0.7,
#     'offensive_rebounds': 9,
#     'defensive_rebounds': 18,
#     'rebounds': 27,
#     'assists': 6,
#     'turnovers': 6,
#     'assists_turnover_ratio': 1.0,
#     'steals': 6,
#     'blocks': 1,
#     'personal_fouls': 11,
#     'tech_fouls': 0,
#     'points': 26,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 0,
#     'true_shooting_att': 31.4,
#     'true_shooting_pct': 0.414,
#     'efficiency': 39},
#    'average': {'minutes': 13.6,
#     'points': 3.3,
#     'off_rebounds': 1.13,
#     'def_rebounds': 2.25,
#     'rebounds': 3.38,
#     'assists': 0.8,
#     'steals': 0.75,
#     'blocks': 0.13,
#     'turnovers': 0.75,
#     'personal_fouls': 1.38,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.0,
#     'field_goals_made': 1.13,
#     'field_goals_att': 3.38,
#     'three_points_made': 0.13,
#     'three_points_att': 0.88,
#     'free_throws_made': 0.88,
#     'free_throws_att': 1.25,
#     'two_points_made': 1.0,
#     'two_points_att': 2.5,
#     'efficiency': 4.88,
#     'true_shooting_att': 3.93}},
#   {'id': '8f0a40cd-d0f6-4986-8253-96d8c91bb18a',
#    'full_name': 'Aljaz Kunc',
#    'first_name': 'Aljaz',
#    'last_name': 'Kunc',
#    'position': 'F',
#    'primary_position': 'NA',
#    'jersey_number': '4',
#    'total': {'games_played': 30,
#     'games_started': 1,
#     'minutes': 355.0,
#     'field_goals_made': 30,
#     'field_goals_att': 66,
#     'field_goals_pct': 0.455,
#     'two_points_made': 18,
#     'two_points_att': 33,
#     'two_points_pct': 0.545,
#     'three_points_made': 12,
#     'three_points_att': 33,
#     'three_points_pct': 0.364,
#     'blocked_att': 1,
#     'free_throws_made': 10,
#     'free_throws_att': 13,
#     'free_throws_pct': 0.769,
#     'offensive_rebounds': 10,
#     'defensive_rebounds': 44,
#     'rebounds': 54,
#     'assists': 13,
#     'turnovers': 20,
#     'assists_turnover_ratio': 0.65,
#     'steals': 13,
#     'blocks': 8,
#     'personal_fouls': 47,
#     'tech_fouls': 0,
#     'points': 82,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 1,
#     'true_shooting_att': 71.72,
#     'true_shooting_pct': 0.572,
#     'efficiency': 111},
#    'average': {'minutes': 11.8,
#     'points': 2.7,
#     'off_rebounds': 0.33,
#     'def_rebounds': 1.47,
#     'rebounds': 1.8,
#     'assists': 0.4,
#     'steals': 0.43,
#     'blocks': 0.27,
#     'turnovers': 0.67,
#     'personal_fouls': 1.57,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.03,
#     'field_goals_made': 1.0,
#     'field_goals_att': 2.2,
#     'three_points_made': 0.4,
#     'three_points_att': 1.1,
#     'free_throws_made': 0.33,
#     'free_throws_att': 0.43,
#     'two_points_made': 0.6,
#     'two_points_att': 1.1,
#     'efficiency': 3.7,
#     'true_shooting_att': 2.39}},
#   {'id': 'a3da6d38-e616-4781-940e-d7635a5bd61f',
#    'full_name': 'Carter Skaggs',
#    'first_name': 'Carter',
#    'last_name': 'Skaggs',
#    'position': 'G',
#    'primary_position': 'NA',
#    'jersey_number': '35',
#    'total': {'games_played': 24,
#     'games_started': 4,
#     'minutes': 403.0,
#     'field_goals_made': 45,
#     'field_goals_att': 117,
#     'field_goals_pct': 0.385,
#     'two_points_made': 8,
#     'two_points_att': 13,
#     'two_points_pct': 0.615,
#     'three_points_made': 37,
#     'three_points_att': 104,
#     'three_points_pct': 0.356,
#     'blocked_att': 1,
#     'free_throws_made': 17,
#     'free_throws_att': 19,
#     'free_throws_pct': 0.895,
#     'offensive_rebounds': 4,
#     'defensive_rebounds': 38,
#     'rebounds': 42,
#     'assists': 17,
#     'turnovers': 19,
#     'assists_turnover_ratio': 0.89,
#     'steals': 7,
#     'blocks': 2,
#     'personal_fouls': 17,
#     'tech_fouls': 0,
#     'points': 144,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 0,
#     'true_shooting_att': 125.36,
#     'true_shooting_pct': 0.574,
#     'efficiency': 119},
#    'average': {'minutes': 16.8,
#     'points': 6.0,
#     'off_rebounds': 0.17,
#     'def_rebounds': 1.58,
#     'rebounds': 1.75,
#     'assists': 0.7,
#     'steals': 0.29,
#     'blocks': 0.08,
#     'turnovers': 0.79,
#     'personal_fouls': 0.71,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.04,
#     'field_goals_made': 1.88,
#     'field_goals_att': 4.88,
#     'three_points_made': 1.54,
#     'three_points_att': 4.33,
#     'free_throws_made': 0.71,
#     'free_throws_att': 0.79,
#     'two_points_made': 0.33,
#     'two_points_att': 0.54,
#     'efficiency': 4.96,
#     'true_shooting_att': 5.22}},
#   {'id': 'b0965b80-0e84-48eb-a31f-5c7233fc5904',
#    'full_name': 'CJ Elleby',
#    'first_name': 'CJ',
#    'last_name': 'Elleby',
#    'position': 'F',
#    'primary_position': 'NA',
#    'jersey_number': '2',
#    'total': {'games_played': 31,
#     'games_started': 27,
#     'minutes': 951.0,
#     'field_goals_made': 165,
#     'field_goals_att': 374,
#     'field_goals_pct': 0.441,
#     'two_points_made': 115,
#     'two_points_att': 253,
#     'two_points_pct': 0.455,
#     'three_points_made': 50,
#     'three_points_att': 121,
#     'three_points_pct': 0.413,
#     'blocked_att': 12,
#     'free_throws_made': 82,
#     'free_throws_att': 123,
#     'free_throws_pct': 0.667,
#     'offensive_rebounds': 50,
#     'defensive_rebounds': 168,
#     'rebounds': 218,
#     'assists': 94,
#     'turnovers': 91,
#     'assists_turnover_ratio': 1.03,
#     'steals': 31,
#     'blocks': 17,
#     'personal_fouls': 82,
#     'tech_fouls': 3,
#     'points': 462,
#     'flagrant_fouls': 1,
#     'ejections': 0,
#     'foulouts': 2,
#     'true_shooting_att': 428.12,
#     'true_shooting_pct': 0.54,
#     'efficiency': 481},
#    'average': {'minutes': 30.7,
#     'points': 14.9,
#     'off_rebounds': 1.61,
#     'def_rebounds': 5.42,
#     'rebounds': 7.03,
#     'assists': 3.0,
#     'steals': 1.0,
#     'blocks': 0.55,
#     'turnovers': 2.94,
#     'personal_fouls': 2.65,
#     'flagrant_fouls': 0.03,
#     'blocked_att': 0.39,
#     'field_goals_made': 5.32,
#     'field_goals_att': 12.06,
#     'three_points_made': 1.61,
#     'three_points_att': 3.9,
#     'free_throws_made': 2.65,
#     'free_throws_att': 3.97,
#     'two_points_made': 3.71,
#     'two_points_att': 8.16,
#     'efficiency': 15.52,
#     'true_shooting_att': 13.81}},
#   {'id': 'b71a2946-0783-409a-b695-eff8a0d51552',
#    'full_name': 'Marvin Cannon',
#    'first_name': 'Marvin',
#    'last_name': 'Cannon',
#    'position': 'F-G',
#    'primary_position': 'NA',
#    'jersey_number': '5',
#    'total': {'games_played': 31,
#     'games_started': 20,
#     'minutes': 669.0,
#     'field_goals_made': 70,
#     'field_goals_att': 160,
#     'field_goals_pct': 0.438,
#     'two_points_made': 53,
#     'two_points_att': 109,
#     'two_points_pct': 0.486,
#     'three_points_made': 17,
#     'three_points_att': 51,
#     'three_points_pct': 0.333,
#     'blocked_att': 13,
#     'free_throws_made': 88,
#     'free_throws_att': 103,
#     'free_throws_pct': 0.854,
#     'offensive_rebounds': 33,
#     'defensive_rebounds': 72,
#     'rebounds': 105,
#     'assists': 19,
#     'turnovers': 36,
#     'assists_turnover_ratio': 0.53,
#     'steals': 17,
#     'blocks': 23,
#     'personal_fouls': 48,
#     'tech_fouls': 0,
#     'points': 245,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 0,
#     'true_shooting_att': 205.32,
#     'true_shooting_pct': 0.597,
#     'efficiency': 268},
#    'average': {'minutes': 21.6,
#     'points': 7.9,
#     'off_rebounds': 1.06,
#     'def_rebounds': 2.32,
#     'rebounds': 3.39,
#     'assists': 0.6,
#     'steals': 0.55,
#     'blocks': 0.74,
#     'turnovers': 1.16,
#     'personal_fouls': 1.55,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.42,
#     'field_goals_made': 2.26,
#     'field_goals_att': 5.16,
#     'three_points_made': 0.55,
#     'three_points_att': 1.65,
#     'free_throws_made': 2.84,
#     'free_throws_att': 3.32,
#     'two_points_made': 1.71,
#     'two_points_att': 3.52,
#     'efficiency': 8.65,
#     'true_shooting_att': 6.62}},
#   {'id': 'd41e82a1-37f8-4a8f-b4a8-f34101a485d7',
#    'full_name': 'Jervae Robinson',
#    'first_name': 'Jervae',
#    'last_name': 'Robinson',
#    'position': 'G',
#    'primary_position': 'NA',
#    'jersey_number': '1',
#    'total': {'games_played': 31,
#     'games_started': 6,
#     'minutes': 547.0,
#     'field_goals_made': 54,
#     'field_goals_att': 143,
#     'field_goals_pct': 0.378,
#     'two_points_made': 35,
#     'two_points_att': 81,
#     'two_points_pct': 0.432,
#     'three_points_made': 19,
#     'three_points_att': 62,
#     'three_points_pct': 0.306,
#     'blocked_att': 6,
#     'free_throws_made': 14,
#     'free_throws_att': 20,
#     'free_throws_pct': 0.7,
#     'offensive_rebounds': 5,
#     'defensive_rebounds': 38,
#     'rebounds': 43,
#     'assists': 57,
#     'turnovers': 40,
#     'assists_turnover_ratio': 1.43,
#     'steals': 12,
#     'blocks': 1,
#     'personal_fouls': 49,
#     'tech_fouls': 0,
#     'points': 141,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 1,
#     'true_shooting_att': 151.8,
#     'true_shooting_pct': 0.464,
#     'efficiency': 119},
#    'average': {'minutes': 17.6,
#     'points': 4.5,
#     'off_rebounds': 0.16,
#     'def_rebounds': 1.23,
#     'rebounds': 1.39,
#     'assists': 1.8,
#     'steals': 0.39,
#     'blocks': 0.03,
#     'turnovers': 1.29,
#     'personal_fouls': 1.58,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.19,
#     'field_goals_made': 1.74,
#     'field_goals_att': 4.61,
#     'three_points_made': 0.61,
#     'three_points_att': 2.0,
#     'free_throws_made': 0.45,
#     'free_throws_att': 0.65,
#     'two_points_made': 1.13,
#     'two_points_att': 2.61,
#     'efficiency': 3.84,
#     'true_shooting_att': 4.9}},
#   {'id': 'e8804c75-f61b-449c-87d3-133c204d068b',
#    'full_name': 'Isaiah Wade',
#    'first_name': 'Isaiah',
#    'last_name': 'Wade',
#    'position': 'F',
#    'primary_position': 'NA',
#    'jersey_number': '0',
#    'total': {'games_played': 27,
#     'games_started': 2,
#     'minutes': 399.0,
#     'field_goals_made': 57,
#     'field_goals_att': 101,
#     'field_goals_pct': 0.564,
#     'two_points_made': 57,
#     'two_points_att': 96,
#     'two_points_pct': 0.594,
#     'three_points_made': 0,
#     'three_points_att': 5,
#     'three_points_pct': 0.0,
#     'blocked_att': 4,
#     'free_throws_made': 15,
#     'free_throws_att': 39,
#     'free_throws_pct': 0.385,
#     'offensive_rebounds': 33,
#     'defensive_rebounds': 63,
#     'rebounds': 96,
#     'assists': 15,
#     'turnovers': 27,
#     'assists_turnover_ratio': 0.56,
#     'steals': 12,
#     'blocks': 3,
#     'personal_fouls': 62,
#     'tech_fouls': 0,
#     'points': 129,
#     'flagrant_fouls': 0,
#     'ejections': 0,
#     'foulouts': 3,
#     'true_shooting_att': 118.16,
#     'true_shooting_pct': 0.546,
#     'efficiency': 160},
#    'average': {'minutes': 14.8,
#     'points': 4.8,
#     'off_rebounds': 1.22,
#     'def_rebounds': 2.33,
#     'rebounds': 3.56,
#     'assists': 0.6,
#     'steals': 0.44,
#     'blocks': 0.11,
#     'turnovers': 1.0,
#     'personal_fouls': 2.3,
#     'flagrant_fouls': 0.0,
#     'blocked_att': 0.15,
#     'field_goals_made': 2.11,
#     'field_goals_att': 3.74,
#     'three_points_made': 0.0,
#     'three_points_att': 0.19,
#     'free_throws_made': 0.56,
#     'free_throws_att': 1.44,
#     'two_points_made': 2.11,
#     'two_points_att': 3.56,
#     'efficiency': 5.93,
#     'true_shooting_att': 4.38}}]}

# %%
team_market.append(teams_response_2["market"])
team_names.append(teams_response_2["name"])
team_ids.append(teams_response_2["id"])
total_games_played.append(teams_response_2["own_record"]["total"]["games_played"])
total_minutes_played.append(teams_response_2["own_record"]["total"]["minutes"])
total_field_goals_made.append(teams_response_2["own_record"]["total"]["field_goals_made"])
total_field_goals_att.append(teams_response_2["own_record"]["total"]["field_goals_att"])
total_field_goals_pct.append(teams_response_2["own_record"]["total"]["two_points_att"])
total_two_points_made.append(teams_response_2["own_record"]["total"]["two_points_made"])
total_two_points_att.append(teams_response_2["own_record"]["total"]["minutes"])
total_two_points_pct.append(teams_response_2["own_record"]["total"]["two_points_pct"])
total_three_points_made.append(teams_response_2["own_record"]["total"]["three_points_made"])
total_three_points_att.append(teams_response_2["own_record"]["total"]["three_points_att"])
total_three_points_pct.append(teams_response_2["own_record"]["total"]["three_points_pct"])
total_blocked_att.append(teams_response_2["own_record"]["total"]["blocked_att"])
total_free_throws_made.append(teams_response_2["own_record"]["total"]["free_throws_made"])
total_free_throws_att.append(teams_response_2["own_record"]["total"]["free_throws_att"])
total_free_throws_pct.append(teams_response_2["own_record"]["total"]["free_throws_pct"])
total_offensive_rebounds.append(teams_response_2["own_record"]["total"]["offensive_rebounds"])
total_defensive_rebounds.append(teams_response_2["own_record"]["total"]["defensive_rebounds"])
total_rebounds.append(teams_response_2["own_record"]["total"]["rebounds"])
total_assists.append(teams_response_2["own_record"]["total"]["assists"])
total_turnovers.append(teams_response_2["own_record"]["total"]["turnovers"])
total_assists_turnover_ratio.append(teams_response_2["own_record"]["total"]["assists_turnover_ratio"])
total_steals.append(teams_response_2["own_record"]["total"]["steals"])
total_blocks.append(teams_response_2["own_record"]["total"]["blocks"])
total_personal_fouls.append(teams_response_2["own_record"]["total"]["personal_fouls"])
total_tech_fouls.append(teams_response_2["own_record"]["total"]["tech_fouls"])
total_points.append(teams_response_2["own_record"]["total"]["points"])
total_fast_break_pts.append(teams_response_2["own_record"]["total"]["fast_break_pts"])
total_flagrant_fouls.append(teams_response_2["own_record"]["total"]["flagrant_fouls"])
total_points_off_turnovers.append(teams_response_2["own_record"]["total"]["points_off_turnovers"])
total_second_chance_pts.append(teams_response_2["own_record"]["total"]["second_chance_pts"])
total_ejections.append(teams_response_2["own_record"]["total"]["ejections"])
total_foulouts.append(teams_response_2["own_record"]["total"]["foulouts"])
total_points_in_paint.append(teams_response_2["own_record"]["total"]["points_in_paint"])
total_efficiency.append(teams_response_2["own_record"]["total"]["efficiency"])
total_true_shooting_att.append(teams_response_2["own_record"]["total"]["true_shooting_att"])
total_true_shooting_pct.append(teams_response_2["own_record"]["total"]["true_shooting_pct"])
average_fast_break_pts.append(teams_response_2["own_record"]["average"]["fast_break_pts"])
average_points_off_turnovers.append(teams_response_2["own_record"]["average"]["points_off_turnovers"])
average_second_chance_pts.append(teams_response_2["own_record"]["average"]["second_chance_pts"])
average_minutes.append(teams_response_2["own_record"]["average"]["minutes"])
average_points.append(teams_response_2["own_record"]["average"]["points"])
average_off_rebounds.append(teams_response_2["own_record"]["average"]["off_rebounds"])
average_def_rebounds.append(teams_response_2["own_record"]["average"]["def_rebounds"])
average_rebounds.append(teams_response_2["own_record"]["average"]["rebounds"])
average_assists.append(teams_response_2["own_record"]["average"]["assists"])
average_steals.append(teams_response_2["own_record"]["average"]["steals"])
average_blocks.append(teams_response_2["own_record"]["average"]["blocks"])
average_turnovers.append(teams_response_2["own_record"]["average"]["turnovers"])
average_personal_fouls.append(teams_response_2["own_record"]["average"]["personal_fouls"])
average_flagrant_fouls.append(teams_response_2["own_record"]["average"]["flagrant_fouls"])
average_blocked_att.append(teams_response_2["own_record"]["average"]["blocked_att"])
average_field_goals_made.append(teams_response_2["own_record"]["average"]["field_goals_made"])
average_field_goals_att.append(teams_response_2["own_record"]["average"]["field_goals_att"])
average_three_points_made.append(teams_response_2["own_record"]["average"]["three_points_made"])
average_three_points_att.append(teams_response_2["own_record"]["average"]["three_points_att"])
average_free_throws_made.append(teams_response_2["own_record"]["average"]["free_throws_made"])
average_free_throws_att.append(teams_response_2["own_record"]["average"]["free_throws_att"])
average_two_points_made.append(teams_response_2["own_record"]["average"]["two_points_made"])
average_two_points_att.append(teams_response_2["own_record"]["average"]["two_points_att"])
average_points_in_paint.append(teams_response_2["own_record"]["average"]["points_in_paint"])
average_efficiency.append(teams_response_2["own_record"]["average"]["efficiency"])
average_true_shooting_att.append(teams_response_2["own_record"]["average"]["true_shooting_att"])

# %%
zippedList = list(zip(team_market,team_names,team_ids,total_games_played,total_three_points_made,total_efficiency,average_true_shooting_att))

# %%
teamdf = pd.DataFrame({"team_market":team_market,
                      "team_name":team_names,
                      "team_id":team_ids,
                      "total_games_played":total_games_played,
                       "total_three_points_made":total_three_points_made,
                       "total_efficiency":total_efficiency,
                       "average_true_shooting_att":average_true_shooting_att
                      })

# %%
teamdf
# Out:
#         team_market team_name                               team_id  \
# 0  Washington State   Cougars  2d4f0015-adb4-4877-8c15-4a6eed7eed03
#
#    total_games_played  total_three_points_made  total_efficiency  \
# 0                  31                      294              2479
#
#    average_true_shooting_att
# 0                      66.12

# %%
#Still trying to get a loop working to pull in all market data
#Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"
#Team_url_2 = "/statistics.json?api_key="
team_market = []
team_names = []
team_ids = []
#Total
total_games_played = []

# %%
for team_id in team_ids:
    Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"
    Team_url_2 = "/statistics.json?api_key="
    Team_response_3 = requests.get(Team_url_1 + str(team_id) + Team_url_2 + api_key).json()
    #Team_url_1 = "http://api.sportradar.us/ncaamb/trial/v4/en/seasons/2018/REG/teams/"+str(team_id)+"/statistics.json?api_key="
    #Team_response_3 = requests.get(Team_url_1 + api_key).json()
    #team_market.append(Team_response_3["market"])
    #team_names.append(Team_response_3["name"])
    #team_ids.append(Team_response_3["id"])
    #total_games_played.append(Team_response_3["own_record"]["total"]["games_played"])
    Team_response_3

# %%
#Team_url_1
Team_response_3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-6b5a1824bb2d> in <module>()
#       1 #Team_url_1
# ----> 2 Team_response_3
#
# NameError: name 'Team_response_3' is not defined

# %%
zippedList = list(zip(team_market,team_names,team_ids,total_games_played))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-afe06ea1a4a8> in <module>()
#       1 zippedList = list(zip(team_market,team_names,team_ids,total_games_played))
#       2 #Team_response_3
# ----> 3 Team_url_1
#
# NameError: name 'Team_url_1' is not defined

# %%
teamdf = pd.DataFrame({"team_market":team_market,
                      "team_name":team_names,
                      "team_id":team_ids,
                      "total_games_played":total_games_played
                      })

# %%
teamdf
